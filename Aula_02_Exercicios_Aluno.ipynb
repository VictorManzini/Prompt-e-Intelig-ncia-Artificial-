# %% [markdown]
# # 📝 Exercícios Práticos — Aula 02: Subáreas da IA
#
# **Disciplina:** Prompt Engineering and Artificial Intelligence
# **Instituição:** FIAP — Ciência da Computação · 2026
# **Professor:** Jorge Luiz Gomes
# **Módulo 1 — Fundamentos de IA**
#
# ---
#
# ## 📋 Instruções
#
# - **8 exercícios** com nível de dificuldade crescente
# - Em cada exercício, complete as partes marcadas com `# 👉 COMPLETE AQUI`
# - **NÃO apague** o código existente — apenas substitua as linhas com `pass`
# - As linhas comentadas logo acima do `pass` são **dicas** do que escrever
# - Execute cada célula com `Shift + Enter` e verifique se funciona
# - Se travar, releia a explicação acima do código
#
# > 💡 **Dica:** A linha comentada com `#` logo acima do `pass` mostra EXATAMENTE o que você precisa escrever. Use como referência!
#
# ---

# %% [markdown]
# ---
# ## Exercício 1 — Seu primeiro classificador de ML ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 1 — Seu primeiro classificador de ML
# ============================================================
# O dataset Iris tem 150 flores com 4 medidas cada:
# - comprimento da sépala
# - largura da sépala
# - comprimento da pétala
# - largura da pétala
# E 3 espécies: setosa, versicolor, virginica

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# 1. Carregar os dados
# 👉 COMPLETE AQUI: iris = load_iris()...
# iris = load_iris()
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: X = iris.data          # As medidas (features)...
# X = iris.data          # As medidas (features)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: y = iris.target        # As espécies (labels)...
# y = iris.target        # As espécies (labels)
pass  # Substitua esta linha

print(f"📊 Dataset Iris:")
print(f"   Total de flores: {len(X)}")
print(f"   Medidas por flor: {X.shape[1]}")
print(f"   Espécies: {list(iris.target_names)}")
print(f"   Exemplo de medidas: {X[0]} → {iris.target_names[y[0]]}")

# 2. Dividir em treino (80%) e teste (20%)
# ✍️ Complete o train_test_split:
# Dica: test_size=0.2 significa 20% para teste
# X_treino, X_teste, y_treino, y_teste = train_test_split(
pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: X, y, test_size=0.2, random_state=42...
    # X, y, test_size=0.2, random_state=42
    pass  # Substitua esta linha
)

print(f"\n📂 Divisão dos dados:")
print(f"   Treino: {len(X_treino)} flores")
print(f"   Teste:  {len(X_teste)} flores")

# 3. Treinar o modelo
# DecisionTree = "Árvore de Decisão"
# É como um fluxograma de perguntas: "pétala > 2.5cm? sim → ..."
# modelo = DecisionTreeClassifier(random_state=42)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: modelo.fit(X_treino, y_treino)  # .fit() = "aprend...
# modelo.fit(X_treino, y_treino)  # .fit() = "aprenda com esses dados"
pass  # Substitua esta linha

# 4. Testar o modelo
# y_previsto = modelo.predict(X_teste)  # .predict() = "agora adivinha"
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: acuracia = accuracy_score(y_teste, y_previsto)...
# acuracia = accuracy_score(y_teste, y_previsto)
pass  # Substitua esta linha

print(f"\n🎯 Resultado:")
print(f"   Acurácia: {acuracia:.1%}")
print(f"   (acertou {int(acuracia * len(y_teste))} de {len(y_teste)} flores)")

# 5. Visualizar
# fig, axes = plt.subplots(1, 2, figsize=(14, 5))
pass  # Substitua esta linha
fig.patch.set_facecolor('#0d0f1a')

# Gráfico 1: dados reais
# cores = ['#6c63ff', '#00d4aa', '#ff6b6b']
pass  # Substitua esta linha
for i, nome in enumerate(iris.target_names):
    # 👉 COMPLETE AQUI: mask = y == i...
    # mask = y == i
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: axes[0].scatter(X[mask, 0], X[mask, 1], c=cores[i]...
    # axes[0].scatter(X[mask, 0], X[mask, 1], c=cores[i], label=nome, alpha=0.7, s=50)
    pass  # Substitua esta linha
# 👉 COMPLETE AQUI: axes[0].set_title("Dados Reais (Sépala)", color='w...
# axes[0].set_title("Dados Reais (Sépala)", color='white', fontsize=12)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: axes[0].set_xlabel("Comprimento", color='white')...
# axes[0].set_xlabel("Comprimento", color='white')
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: axes[0].set_ylabel("Largura", color='white')...
# axes[0].set_ylabel("Largura", color='white')
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: axes[0].legend(facecolor='#1a1040', labelcolor='wh...
# axes[0].legend(facecolor='#1a1040', labelcolor='white')
pass  # Substitua esta linha
axes[0].set_facecolor('#141628')
axes[0].tick_params(colors='white')

# Gráfico 2: importância das features
importancias = modelo.feature_importances_
nomes_features = ['Sépala\nCompr.', 'Sépala\nLarg.', 'Pétala\nCompr.', 'Pétala\nLarg.']
axes[1].bar(nomes_features, importancias, color=cores + ['#ffd166'], alpha=0.85)
axes[1].set_title("Importância de cada Medida", color='white', fontsize=12)
axes[1].set_facecolor('#141628')
axes[1].tick_params(colors='white')

for ax in axes:
    for spine in ax.spines.values():
        spine.set_color('#2a2d4a')

plt.tight_layout()
plt.show()

print("\n💡 A pétala é MUITO mais importante que a sépala para classificar!")

# %% [markdown]
# ---
# ## Exercício 2 — Explorando 3 tarefas de NLP ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 2 — Explorando 3 tarefas de NLP
# ============================================================
from transformers import pipeline

print("⏳ Carregando modelos de NLP...")

# Tarefa 1: Análise de sentimento
# 👉 COMPLETE AQUI: sentimento = pipeline("sentiment-analysis")...
# sentimento = pipeline("sentiment-analysis")
pass  # Substitua esta linha

# Tarefa 2: Reconhecimento de entidades nomeadas (NER)
# ner = pipeline("ner", aggregation_strategy="simple")
pass  # Substitua esta linha

# Tarefa 3: Responder perguntas (Question Answering)
# qa = pipeline("question-answering")
pass  # Substitua esta linha

print("✅ Modelos carregados!\n")

# ── TAREFA 1: Sentimento ──
print("1️⃣ ANÁLISE DE SENTIMENTO")
print("─" * 40)
# ✍️ Troque por frases suas!
# frases_sentimento = [
pass  # Substitua esta linha
    "I absolutely love this AI course at FIAP!",
    "Machine learning is confusing and frustrating.",
    "The weather is cloudy today.",
]

for frase in frases_sentimento:
    # 👉 COMPLETE AQUI: r = sentimento(frase)[0]...
    # r = sentimento(frase)[0]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: emoji = "😊" if r['label'] == 'POSITIVE' else "😟"...
    # emoji = "😊" if r['label'] == 'POSITIVE' else "😟"
    pass  # Substitua esta linha
    print(f"  {emoji} {frase[:50]:<50} → {r['label']} ({r['score']:.0%})")

# ── TAREFA 2: NER ──
print(f"\n2️⃣ RECONHECIMENTO DE ENTIDADES (NER)")
print("─" * 40)
# ✍️ Troque por um texto com nomes de pessoas, empresas e lugares!
# texto_ner = "Mark Zuckerberg is the CEO of Meta, headquartered in Menlo Park, California."
pass  # Substitua esta linha

# entidades = ner(texto_ner)
pass  # Substitua esta linha
print(f"  Texto: {texto_ner}\n")
for e in entidades:
    # 👉 COMPLETE AQUI: tipo_emoji = {"PER": "👤", "ORG": "🏢", "LOC": "📍", ...
    # tipo_emoji = {"PER": "👤", "ORG": "🏢", "LOC": "📍", "MISC": "🏷️"}
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: emoji = tipo_emoji.get(e['entity_group'], "🏷️")...
    # emoji = tipo_emoji.get(e['entity_group'], "🏷️")
    pass  # Substitua esta linha
    print(f"  {emoji} {e['entity_group']}: {e['word']:<20} (confiança: {e['score']:.0%})")

# ── TAREFA 3: Question Answering ──
print(f"\n3️⃣ RESPONDER PERGUNTAS (Q&A)")
print("─" * 40)
# A IA lê um contexto e responde perguntas sobre ele
# contexto = "FIAP is a technology university located in São Paulo, Brazil. It was founded in 1995 and offers courses in Computer Science, Artificial Intelligence, and Software Engineering. The campus is located on Paulista Avenue."
pass  # Substitua esta linha

# ✍️ Faça suas próprias perguntas sobre o contexto!
# perguntas = [
pass  # Substitua esta linha
    "Where is FIAP located?",
    "When was FIAP founded?",
    "What courses does FIAP offer?",
]

print(f"  Contexto: {contexto[:80]}...\n")
for pergunta in perguntas:
    # 👉 COMPLETE AQUI: r = qa(question=pergunta, context=contexto)...
    # r = qa(question=pergunta, context=contexto)
    pass  # Substitua esta linha
    print(f"  ❓ {pergunta}")
    print(f"  💡 {r['answer']} (confiança: {r['score']:.0%})\n")

# %% [markdown]
# ---
# ## Exercício 3 — Classificação de Imagens ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 3 — Classificação de Imagens
# ============================================================
from transformers import pipeline
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

print("⏳ Carregando modelo de visão...")
# 👉 COMPLETE AQUI: classificador = pipeline("image-classification", m...
# classificador = pipeline("image-classification", model="google/vit-base-patch16-224")
pass  # Substitua esta linha
print("✅ Modelo carregado!\n")

# ✍️ TROQUE AS URLs por imagens que você quiser!
# Dica: use imagens do Wikipedia ou Unsplash
# imagens = [
pass  # Substitua esta linha
    {
        "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Cat_November_2010-1a.jpg/1200px-Cat_November_2010-1a.jpg",
        "descricao": "Gato"
    },
    {
        "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/2/26/YellowLabradorLooking_new.jpg/1200px-YellowLabradorLooking_new.jpg",
        "descricao": "Cachorro"
    },
    {
        "url": "https://upload.wikimedia.org/wikipedia/commons/thumb/a/a7/Camponotus_flavomarginatus_ant.jpg/1200px-Camponotus_flavomarginatus_ant.jpg",
        "descricao": "Formiga"
    },
]

# fig, axes = plt.subplots(1, len(imagens), figsize=(5*len(imagens), 5))
pass  # Substitua esta linha
fig.patch.set_facecolor('#0d0f1a')

for idx, img_info in enumerate(imagens):
    try:
        # Baixar imagem
        # response = requests.get(img_info['url'], timeout=15)
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: imagem = Image.open(BytesIO(response.content))...
        # imagem = Image.open(BytesIO(response.content))
        pass  # Substitua esta linha

        # Classificar
        # resultados = classificador(imagem)
        pass  # Substitua esta linha

        # Mostrar imagem
        axes[idx].imshow(imagem)
        # 👉 COMPLETE AQUI: axes[idx].set_title(f"Esperado: {img_info['descric...
        # axes[idx].set_title(f"Esperado: {img_info['descricao']}", color='white', fontsize=11)
        pass  # Substitua esta linha
        axes[idx].axis('off')

        # Mostrar resultado
        # top = resultados[0]
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: print(f"🖼️ Imagem {idx+1} ({img_info['descricao']}...
        # print(f"🖼️ Imagem {idx+1} ({img_info['descricao']}):")
        pass  # Substitua esta linha
        for r in resultados[:3]:
            # 👉 COMPLETE AQUI: barra = "█" * int(r['score'] * 30)...
            # barra = "█" * int(r['score'] * 30)
            pass  # Substitua esta linha
            # 👉 COMPLETE AQUI: print(f"   {r['label']:<30} {r['score']:.1%} {barr...
            # print(f"   {r['label']:<30} {r['score']:.1%} {barra}")
            pass  # Substitua esta linha
        print()

    except Exception as e:
        # 👉 COMPLETE AQUI: print(f"⚠️ Erro na imagem {idx+1}: {e}")...
        # print(f"⚠️ Erro na imagem {idx+1}: {e}")
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: axes[idx].text(0.5, 0.5, 'Erro', ha='center', va='...
        # axes[idx].text(0.5, 0.5, 'Erro', ha='center', va='center', color='white')
        pass  # Substitua esta linha
        axes[idx].set_facecolor('#141628')

plt.tight_layout()
plt.show()

print("💡 O modelo foi treinado no ImageNet (14 milhões de imagens, 1000 classes).")
print("   Ele reconhece objetos, animais, veículos, alimentos e muito mais!")

# %% [markdown]
# ---
# ## Exercício 4 — Supervisionado vs Não-Supervisionado ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 4 — Supervisionado vs Não-Supervisionado
# ============================================================
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# Gerar dados sintéticos (3 grupos)
# 👉 COMPLETE AQUI: X, y_real = make_blobs(n_samples=300, centers=3, c...
# X, y_real = make_blobs(n_samples=300, centers=3, cluster_std=1.2, random_state=42)
pass  # Substitua esta linha

# fig, axes = plt.subplots(1, 3, figsize=(18, 5))
pass  # Substitua esta linha
fig.patch.set_facecolor('#0d0f1a')
# 👉 COMPLETE AQUI: cores = ['#6c63ff', '#00d4aa', '#ff6b6b']...
# cores = ['#6c63ff', '#00d4aa', '#ff6b6b']
pass  # Substitua esta linha

# ── GRÁFICO 1: Dados sem rótulos (como o computador vê) ──
# axes[0].scatter(X[:, 0], X[:, 1], c='#888888', alpha=0.5, s=40)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: axes[0].set_title("1. Dados SEM rótulos\n(como o c...
# axes[0].set_title("1. Dados SEM rótulos\n(como o computador recebe)", color='white', fontsize=11)
pass  # Substitua esta linha
axes[0].set_facecolor('#141628')
# 👉 COMPLETE AQUI: axes[0].tick_params(colors='white')...
# axes[0].tick_params(colors='white')
pass  # Substitua esta linha

# ── GRÁFICO 2: Não-supervisionado (K-Means encontra grupos sozinho) ──
# ✍️ Complete: quantos clusters (k) o K-Means deve encontrar?
# kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)  # ← ajuste n_clusters!
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: y_kmeans = kmeans.fit_predict(X)...
# y_kmeans = kmeans.fit_predict(X)
pass  # Substitua esta linha

for i in range(3):
    # 👉 COMPLETE AQUI: mask = y_kmeans == i...
    # mask = y_kmeans == i
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: axes[1].scatter(X[mask, 0], X[mask, 1], c=cores[i]...
    # axes[1].scatter(X[mask, 0], X[mask, 1], c=cores[i], alpha=0.6, s=40)
    pass  # Substitua esta linha
# Mostrar centróides
axes[1].scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1],
                # 👉 COMPLETE AQUI: c='white', marker='X', s=200, edgecolors='black', ...
                # c='white', marker='X', s=200, edgecolors='black', linewidths=2, zorder=5)
                pass  # Substitua esta linha
# 👉 COMPLETE AQUI: axes[1].set_title("2. NÃO-SUPERVISIONADO (K-Means)...
# axes[1].set_title("2. NÃO-SUPERVISIONADO (K-Means)\n(encontrou grupos sozinho!)", color='white', fontsize=11)
pass  # Substitua esta linha
axes[1].set_facecolor('#141628')
# 👉 COMPLETE AQUI: axes[1].tick_params(colors='white')...
# axes[1].tick_params(colors='white')
pass  # Substitua esta linha

# ── GRÁFICO 3: Supervisionado (classificou com rótulos) ──
X_tr, X_te, y_tr, y_te = train_test_split(X, y_real, test_size=0.3, random_state=42)
rf = RandomForestClassifier(random_state=42)
# 👉 COMPLETE AQUI: rf.fit(X_tr, y_tr)...
# rf.fit(X_tr, y_tr)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: y_pred = rf.predict(X)...
# y_pred = rf.predict(X)
pass  # Substitua esta linha

for i in range(3):
    mask = y_pred == i
    axes[2].scatter(X[mask, 0], X[mask, 1], c=cores[i], alpha=0.6, s=40)
acc = accuracy_score(y_real, y_pred)
axes[2].set_title(f"3. SUPERVISIONADO (Random Forest)\n(usou rótulos — acurácia: {acc:.0%})", color='white', fontsize=11)
axes[2].set_facecolor('#141628')
axes[2].tick_params(colors='white')

for ax in axes:
    for spine in ax.spines.values():
        spine.set_color('#2a2d4a')

plt.tight_layout()
plt.show()

print("🔑 DIFERENÇAS FUNDAMENTAIS:")
print("   • Não-supervisionado: NÃO tem gabarito → encontra padrões sozinho")
print("   • Supervisionado: TEM gabarito → aprende com exemplos rotulados")
print("   • K-Means pode achar grupos DIFERENTES dos reais (veja se as cores batem!)")

# %% [markdown]
# ---
# ## Exercício 5 — IA Generativa: Texto + Imagem ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 5 — IA Generativa: Texto + Imagem
# ============================================================
from transformers import pipeline
from PIL import Image
import requests
from io import BytesIO

# ── PARTE A: Geração de texto ──
print("📝 PARTE A: Geração de Texto (GPT-2)\n")
# 👉 COMPLETE AQUI: gerador = pipeline("text-generation", model="gpt2"...
# gerador = pipeline("text-generation", model="gpt2")
pass  # Substitua esta linha

# ✍️ Crie 3 prompts sobre temas que você gosta!
# meus_prompts = [
pass  # Substitua esta linha
    "The future of artificial intelligence in Brazil is",
    "The best way to learn programming is",
    "In 2030, robots will",
]

for prompt in meus_prompts:
    # 👉 COMPLETE AQUI: resultado = gerador(prompt, max_length=50, tempera...
    # resultado = gerador(prompt, max_length=50, temperature=0.7, do_sample=True)
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: texto = resultado[0]['generated_text']...
    # texto = resultado[0]['generated_text']
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: print(f"  📝 {prompt}")...
    # print(f"  📝 {prompt}")
    pass  # Substitua esta linha
    print(f"  🤖 {texto[len(prompt):].strip()[:100]}\n")

# ── PARTE B: Descrição de imagem ──
print("\n🖼️ PARTE B: Descrição de Imagem (BLIP)\n")
# 👉 COMPLETE AQUI: describer = pipeline("image-to-text", model="Sales...
# describer = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
pass  # Substitua esta linha

# ✍️ Troque a URL por uma imagem diferente!
# url = "https://upload.wikimedia.org/wikipedia/commons/thumb/1/10/Empire_State_Building_%28aerial_view%29.jpg/800px-Empire_State_Building_%28aerial_view%29.jpg"
pass  # Substitua esta linha

try:
    # 👉 COMPLETE AQUI: img = Image.open(BytesIO(requests.get(url, timeout...
    # img = Image.open(BytesIO(requests.get(url, timeout=15).content))
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: resultado = describer(img)...
    # resultado = describer(img)
    pass  # Substitua esta linha
    print(f"  🖼️ Imagem: Empire State Building")
    print(f"  🤖 IA descreveu: {resultado[0]['generated_text']}")
    print(f"\n  💡 A IA 'olhou' para a imagem e descreveu em palavras!")
    print(f"     Isso é multimodalidade: combinar visão + linguagem.")
except Exception as e:
    print(f"  ⚠️ Erro: {e}")

# %% [markdown]
# ---
# ## Exercício 6 — Quiz: Qual subárea da IA? ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 6 — Quiz: Qual subárea da IA?
# ============================================================

# 👉 COMPLETE AQUI: cenarios = [...
# cenarios = [
pass  # Substitua esta linha
    {
        "cenario": "O Spotify analisa suas músicas favoritas e sugere uma playlist personalizada.",
        "opcoes": ["A) NLP", "B) Computer Vision", "C) Machine Learning (Recomendação)", "D) Robótica"],
        "correta": "C",
        "explicacao": "Sistemas de recomendação usam ML para encontrar padrões no que você gosta."
    },
    {
        "cenario": "O Google Tradutor converte um texto de português para japonês.",
        "opcoes": ["A) Computer Vision", "B) NLP", "C) Robótica", "D) Machine Learning básico"],
        "correta": "B",
        "explicacao": "Tradução é uma tarefa clássica de NLP (Processamento de Linguagem Natural)."
    },
    {
        "cenario": "Uma câmera de segurança detecta automaticamente quando alguém entra na loja.",
        "opcoes": ["A) NLP", "B) IA Generativa", "C) Computer Vision", "D) Aprendizado por Reforço"],
        "correta": "C",
        "explicacao": "Detecção de pessoas em vídeo é Computer Vision (visão computacional)."
    },
    {
        "cenario": "O Midjourney cria uma imagem artística a partir de uma descrição em texto.",
        "opcoes": ["A) Machine Learning", "B) IA Generativa", "C) NLP", "D) Robótica"],
        "correta": "B",
        # 👉 COMPLETE AQUI: "explicacao": "Criar imagens novas = IA Generativa...
        # "explicacao": "Criar imagens novas = IA Generativa. Combina NLP (entender o texto) + geração de imagem."
        pass  # Substitua esta linha
    },
    {
        "cenario": "Um robô aspirador mapeia a casa e desvia de obstáculos sozinho.",
        "opcoes": ["A) NLP", "B) Deep Learning", "C) Robótica + Computer Vision", "D) IA Generativa"],
        "correta": "C",
        # 👉 COMPLETE AQUI: "explicacao": "O robô usa sensores (visão) + plane...
        # "explicacao": "O robô usa sensores (visão) + planejamento de rota + atuação física = Robótica + CV."
        pass  # Substitua esta linha
    },
    {
        "cenario": "O banco Nubank detecta uma compra suspeita no seu cartão em tempo real.",
        "opcoes": ["A) NLP", "B) Machine Learning (Detecção de Anomalias)", "C) Robótica", "D) IA Generativa"],
        "correta": "B",
        "explicacao": "Detecção de fraude usa ML para identificar padrões anormais nos dados de transação."
    },
]

# pontos = 0
pass  # Substitua esta linha
print("🔍 QUIZ — DETETIVE DE IA: Qual subárea?\n")
# 👉 COMPLETE AQUI: print("=" * 50)...
# print("=" * 50)
pass  # Substitua esta linha

for i, q in enumerate(cenarios, 1):
    # 👉 COMPLETE AQUI: print(f"\nCenário {i}/{len(cenarios)}:")...
    # print(f"\nCenário {i}/{len(cenarios)}:")
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: print(f"  📌 {q['cenario']}\n")...
    # print(f"  📌 {q['cenario']}\n")
    pass  # Substitua esta linha
    for op in q['opcoes']:
        # 👉 COMPLETE AQUI: print(f"     {op}")...
        # print(f"     {op}")
        pass  # Substitua esta linha

    # resp = input(f"\n  Sua resposta (A/B/C/D): ").strip().upper()
    pass  # Substitua esta linha
    if resp == q['correta']:
        # 👉 COMPLETE AQUI: pontos += 1...
        # pontos += 1
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: print(f"  ✅ Correto! {q['explicacao']}")...
        # print(f"  ✅ Correto! {q['explicacao']}")
        pass  # Substitua esta linha
    else:
        # 👉 COMPLETE AQUI: print(f"  ❌ Resposta: {q['correta']}. {q['explicac...
        # print(f"  ❌ Resposta: {q['correta']}. {q['explicacao']}")
        pass  # Substitua esta linha

# print(f"\n{'=' * 50}")
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: print(f"🏆 Resultado: {pontos}/{len(cenarios)} ({po...
# print(f"🏆 Resultado: {pontos}/{len(cenarios)} ({pontos/len(cenarios)*100:.0f}%)")
pass  # Substitua esta linha

# %% [markdown]
# ---
# ## Exercício 7 — Comparar 2 modelos de sentimento ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 7 — Comparar 2 modelos de sentimento
# ============================================================
from transformers import pipeline
import time

# Modelo 1: DistilBERT (padrão, rápido)
print("⏳ Carregando Modelo 1 (DistilBERT)...")
# 👉 COMPLETE AQUI: modelo1 = pipeline("sentiment-analysis")...
# modelo1 = pipeline("sentiment-analysis")
pass  # Substitua esta linha

# Modelo 2: RoBERTa (mais preciso, mais lento)
print("⏳ Carregando Modelo 2 (RoBERTa)...")
# 👉 COMPLETE AQUI: modelo2 = pipeline("sentiment-analysis", model="ca...
# modelo2 = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest")
pass  # Substitua esta linha

print("✅ Ambos carregados!\n")

# ✍️ Adicione seus próprios textos de teste!
# textos_teste = [
pass  # Substitua esta linha
    "This movie was absolutely fantastic, I loved every minute!",
    "Terrible service, I will never come back.",
    "The food was okay, nothing special but not bad either.",
    "I can't believe how amazing this AI course is!",
    "The product broke after one day. Very disappointed.",
    "It's fine I guess.",
]

print(f"{'Texto':<55} {'Modelo 1':<18} {'Modelo 2'}")
print("═" * 95)

for texto in textos_teste:
    # Modelo 1
    # t1 = time.time()
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: r1 = modelo1(texto)[0]...
    # r1 = modelo1(texto)[0]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: tempo1 = time.time() - t1...
    # tempo1 = time.time() - t1
    pass  # Substitua esta linha

    # Modelo 2
    # t2 = time.time()
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: r2 = modelo2(texto)[0]...
    # r2 = modelo2(texto)[0]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: tempo2 = time.time() - t2...
    # tempo2 = time.time() - t2
    pass  # Substitua esta linha

    # e1 = "😊" if "POS" in r1['label'].upper() or r1['label'] == "POSITIVE" else "😟" if "NEG" in r1['label'].upper() or r1['label'] == "NEGATIVE" else "😐"
    pass  # Substitua esta linha
    e2 = "😊" if "POS" in r2['label'].upper() or r2['label'] == "POSITIVE" else "😟" if "NEG" in r2['label'].upper() or r2['label'] == "NEGATIVE" else "😐"

    print(f"  {texto[:53]:<53} {e1} {r1['score']:.0%} ({tempo1:.2f}s)   {e2} {r2['score']:.0%} ({tempo2:.2f}s)")

print("\n🤔 PERGUNTAS:")
print("   1. Os modelos concordaram em todos os textos?")
print("   2. Qual modelo parece mais preciso nas frases neutras?")
print("   3. Qual foi mais rápido?")

# %% [markdown]
# ---
# ## Exercício 8 — Crie seu próprio dataset e treine um modelo ⭐⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 8 — Crie seu próprio dataset e treine um modelo
# ============================================================
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# ✍️ Crie seu dataset de classificação de textos!
# Tema: classificar mensagens como URGENTE, NORMAL ou SPAM
# Adicione pelo menos 5 exemplos por categoria

# 👉 COMPLETE AQUI: textos = [...
# textos = [
pass  # Substitua esta linha
    # URGENTES
    "SERVIDOR FORA DO AR! Clientes não conseguem acessar o sistema!",
    "Bug crítico em produção, dados sendo perdidos agora!",
    "Sistema de pagamento parou de funcionar, vendas paradas!",
    "Invasão detectada! Precisamos agir imediatamente!",
    "Cliente VIP reclamando, precisamos resolver em 1 hora!",
    # NORMAIS
    "Podemos agendar uma reunião para discutir o projeto?",
    "Enviei o relatório mensal para sua aprovação.",
    "O novo estagiário começa na segunda-feira.",
    "Atualização do sistema agendada para o próximo sábado.",
    "Lembrete: treinamento de segurança amanhã às 14h.",
    # SPAM
    "GANHE DINHEIRO FÁCIL! Clique aqui agora!!!",
    "Parabéns! Você ganhou um iPhone grátis!",
    "Oferta imperdível: 90% de desconto só hoje!",
    "Seu cadastro foi selecionado para um prêmio especial!",
    "Ganhe seguidores grátis! Acesse agora!",
    # ✍️ Adicione mais exemplos aqui para melhorar o modelo!
]

# categorias = (
pass  # Substitua esta linha
    ["URGENTE"] * 5 +
    ["NORMAL"] * 5 +
    ["SPAM"] * 5
)

# Transformar texto em números (TF-IDF)
# TF-IDF = conta quais palavras são mais importantes em cada texto
# vectorizer = TfidfVectorizer(max_features=100)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: X = vectorizer.fit_transform(textos)...
# X = vectorizer.fit_transform(textos)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: y = categorias...
# y = categorias
pass  # Substitua esta linha

# Treinar modelo
# X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.3, random_state=42)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: modelo = MultinomialNB()...
# modelo = MultinomialNB()
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: modelo.fit(X_tr, y_tr)...
# modelo.fit(X_tr, y_tr)
pass  # Substitua esta linha

# Avaliar
# y_pred = modelo.predict(X_te)
pass  # Substitua esta linha
print("📊 RESULTADO DO SEU CLASSIFICADOR\n")
print(classification_report(y_te, y_pred))

# Testar com textos novos
print("\n🧪 TESTANDO COM TEXTOS NOVOS:")
# 👉 COMPLETE AQUI: novos = [...
# novos = [
pass  # Substitua esta linha
    "O servidor vai cair se não fizermos manutenção!",
    "Bom dia, segue o documento solicitado.",
    "CLIQUE AQUI e ganhe R$5000 agora!!!",
]

for texto in novos:
    # 👉 COMPLETE AQUI: previsao = modelo.predict(vectorizer.transform([te...
    # previsao = modelo.predict(vectorizer.transform([texto]))[0]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: emoji = {"URGENTE": "🚨", "NORMAL": "📩", "SPAM": "🗑...
    # emoji = {"URGENTE": "🚨", "NORMAL": "📩", "SPAM": "🗑️"}
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: print(f"  {emoji.get(previsao, '❓')} '{texto[:50]}...
    # print(f"  {emoji.get(previsao, '❓')} '{texto[:50]}...' → {previsao}")
    pass  # Substitua esta linha

# %% [markdown]
# ---
# ## 🎉 Parabéns!
#
# Você completou os 8 exercícios da **Aula 02 — Subáreas da IA**!
#
# **O que você aprendeu:**
# - Cada exercício praticou um conceito diferente da aula
# - Você escreveu código Python funcional no Google Colab
# - Os conceitos se conectam com o conteúdo teórico da aula
#
# **Salve seu notebook** (File → Save) para não perder o progresso!
