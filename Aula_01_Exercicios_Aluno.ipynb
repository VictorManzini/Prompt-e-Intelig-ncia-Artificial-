# %% [markdown]
# # 📝 Exercícios Práticos — Aula 01: O que é IA?
#
# **Disciplina:** Prompt Engineering and Artificial Intelligence
# **Instituição:** FIAP — Ciência da Computação · 2026
# **Professor:** Jorge Luiz Gomes
# **Módulo 1 — Fundamentos de IA**
#
# ---
#
# ## 📋 Instruções
#
# - **10 exercícios** com nível de dificuldade crescente
# - Em cada exercício, complete as partes marcadas com `# 👉 COMPLETE AQUI`
# - **NÃO apague** o código existente — apenas substitua as linhas com `pass`
# - As linhas comentadas logo acima do `pass` são **dicas** do que escrever
# - Execute cada célula com `Shift + Enter` e verifique se funciona
# - Se travar, releia a explicação acima do código
#
# > 💡 **Dica:** A linha comentada com `#` logo acima do `pass` mostra EXATAMENTE o que você precisa escrever. Use como referência!
#
# ---

# %% [markdown]
# ---
# ## Exercício 1 — Classificando Produtos de IA ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 1 — Classificando Produtos de IA
# ============================================================
# Cada produto abaixo usa alguma subárea da IA.
# Sua tarefa: preencha a categoria correta para cada um.
#
# Categorias possíveis:
#   "IA Generativa"    → gera conteúdo novo (texto, imagem, código)
#   "Machine Learning"  → aprende padrões a partir de dados
#   "Computer Vision"   → entende imagens e vídeos
#   "NLP"              → entende e gera linguagem humana
#   "Robótica"         → controla robôs e sistemas físicos

# Aqui temos um dicionário onde:
# - A chave (antes do :) é o nome do produto
# - O valor (depois do :) é a categoria — você precisa preencher!

# 👉 COMPLETE AQUI: produtos_ia = {...
# produtos_ia = {
pass  # Substitua esta linha
    "ChatGPT":          "???",    # ✍️ Troque "???" pela categoria correta
    "Google Tradutor":  "???",    # ✍️
    "Netflix (recomendações)": "???",  # ✍️
    "Tesla Autopilot":  "???",    # ✍️
    "Midjourney":       "???",    # ✍️
    "Alexa (Amazon)":   "???",    # ✍️
    "GitHub Copilot":   "???",    # ✍️
    "Spotify (Discover Weekly)": "???",  # ✍️
    "Google Lens":      "???",    # ✍️
    "Waze (rotas)":     "???",    # ✍️
}

# Código para mostrar sua classificação de forma bonita
# (não precisa alterar nada abaixo!)
print("🏷️ Sua Classificação de Produtos de IA\n")
# 👉 COMPLETE AQUI: print(f"{'Produto':<30} {'Categoria'}")...
# print(f"{'Produto':<30} {'Categoria'}")
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: print("=" * 55)...
# print("=" * 55)
pass  # Substitua esta linha

for produto, categoria in produtos_ia.items():
    # Escolhe um emoji baseado na categoria
    # emojis = {
    pass  # Substitua esta linha
        "IA Generativa": "🎨",
        "Machine Learning": "📊",
        "Computer Vision": "👁️",
        "NLP": "🗣️",
        "Robótica": "🤖",
        "???": "❓"
    }
    # 👉 COMPLETE AQUI: emoji = emojis.get(categoria, "❓")...
    # emoji = emojis.get(categoria, "❓")
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: print(f"  {emoji} {produto:<28} {categoria}")...
    # print(f"  {emoji} {produto:<28} {categoria}")
    pass  # Substitua esta linha

# Contar quantos você já classificou
# classificados = sum(1 for v in produtos_ia.values() if v != "???")
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: print(f"\n📊 Progresso: {classificados}/{len(produt...
# print(f"\n📊 Progresso: {classificados}/{len(produtos_ia)} classificados")
pass  # Substitua esta linha

if classificados == len(produtos_ia):
    print("🎉 Parabéns! Você classificou todos!")

# %%
# ============================================================
# EXERCÍCIO 10 — Pesquisa: IA no Brasil
# ============================================================
import matplotlib.pyplot as plt

# ✍️ PREENCHA COM SUA PESQUISA!
# Para cada empresa, preencha:
# - nome: nome da empresa
# - setor: área de atuação (fintech, saúde, varejo, etc.)
# - uso_ia: o que fazem com IA
# - impacto: número de impacto (ex: "40 milhões de clientes")

# 👉 COMPLETE AQUI: empresas_ia_brasil = [...
# empresas_ia_brasil = [
pass  # Substitua esta linha
    {
        "nome": "Nubank",
        "setor": "Fintech",
        "uso_ia": "Detecção de fraude e análise de crédito",
        "impacto": "100M+ de clientes"
    },
    {
        "nome": "???",        # ✍️ Pesquise e preencha!
        "setor": "???",
        "uso_ia": "???",
        "impacto": "???"
    },
    {
        "nome": "???",        # ✍️ Pesquise e preencha!
        "setor": "???",
        "uso_ia": "???",
        "impacto": "???"
    },
    {
        "nome": "???",        # ✍️ Pesquise e preencha!
        "setor": "???",
        "uso_ia": "???",
        "impacto": "???"
    },
    {
        "nome": "???",        # ✍️ Pesquise e preencha!
        "setor": "???",
        "uso_ia": "???",
        "impacto": "???"
    },
]

# ── Gerar relatório ──
print("📊 RELATÓRIO: IA NO MERCADO BRASILEIRO\n")
# 👉 COMPLETE AQUI: print(f"{'#':<4} {'Empresa':<18} {'Setor':<15} {'U...
# print(f"{'#':<4} {'Empresa':<18} {'Setor':<15} {'Uso de IA':<40} {'Impacto'}")
pass  # Substitua esta linha
print("═" * 95)

for i, emp in enumerate(empresas_ia_brasil, 1):
    # 👉 COMPLETE AQUI: print(f"  {i:<3} {emp['nome']:<17} {emp['setor']:<...
    # print(f"  {i:<3} {emp['nome']:<17} {emp['setor']:<14} {emp['uso_ia'][:38]:<39} {emp['impacto']}")
    pass  # Substitua esta linha

# ── Gráfico de setores ──
# Contar quantas empresas por setor
# setores = {}
pass  # Substitua esta linha
for emp in empresas_ia_brasil:
    # 👉 COMPLETE AQUI: setor = emp['setor']...
    # setor = emp['setor']
    pass  # Substitua esta linha
    if setor != "???":
        # 👉 COMPLETE AQUI: setores[setor] = setores.get(setor, 0) + 1...
        # setores[setor] = setores.get(setor, 0) + 1
        pass  # Substitua esta linha

if setores:
    # 👉 COMPLETE AQUI: fig, ax = plt.subplots(figsize=(8, 5))...
    # fig, ax = plt.subplots(figsize=(8, 5))
    pass  # Substitua esta linha
    fig.patch.set_facecolor('#0d0f1a')
    ax.set_facecolor('#141628')

    # cores = ['#6c63ff', '#00d4aa', '#ffd166', '#ff6b6b', '#06b6d4', '#e91e63']
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ax.bar(setores.keys(), setores.values(), color=cor...
    # ax.bar(setores.keys(), setores.values(), color=cores[:len(setores)],
    pass  # Substitua esta linha
           # 👉 COMPLETE AQUI: alpha=0.85, edgecolor='white', linewidth=0.5)...
           # alpha=0.85, edgecolor='white', linewidth=0.5)
           pass  # Substitua esta linha
    ax.set_title("Setores que mais usam IA no Brasil (sua pesquisa)",
                 # 👉 COMPLETE AQUI: color='white', fontsize=12, fontweight='bold')...
                 # color='white', fontsize=12, fontweight='bold')
                 pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ax.set_ylabel("Quantidade de empresas", color='whi...
    # ax.set_ylabel("Quantidade de empresas", color='white')
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ax.tick_params(colors='white')...
    # ax.tick_params(colors='white')
    pass  # Substitua esta linha
    for spine in ax.spines.values():
        spine.set_color('#2a2d4a')
    plt.tight_layout()
    plt.show()

# Contar progresso
# preenchidos = sum(1 for e in empresas_ia_brasil if e['nome'] != '???')
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: print(f"\n📊 Progresso: {preenchidos}/{len(empresas...
# print(f"\n📊 Progresso: {preenchidos}/{len(empresas_ia_brasil)} empresas pesquisadas")
pass  # Substitua esta linha

if preenchidos < 5:
    print("\n💡 Dica: pesquise por 'empresas brasileiras que usam inteligência artificial'")
    print("   Algumas para começar: iFood, Stone, Totvs, Vtex, C6 Bank, Magazine Luiza, Loft")

# %% [markdown]
# ---
# ## Exercício 2 — Apresentação + Primeiro contato com variáveis ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 2 — Apresentação + Primeiro contato com variáveis
# ============================================================
# Variáveis são "caixas" que guardam informações.
# O sinal = significa "guarde este valor nesta variável".

# ✍️ Preencha com suas informações:
# 👉 COMPLETE AQUI: meu_nome = "???"               # Troque pelo seu n...
# meu_nome = "???"               # Troque pelo seu nome (entre aspas!)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: minha_turma = "???"             # Ex: "1CCPR-2025"...
# minha_turma = "???"             # Ex: "1CCPR-2025" ou "1CCR-2026"
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: minha_idade = 0                 # Troque pelo seu ...
# minha_idade = 0                 # Troque pelo seu número (SEM aspas!)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: minha_ferramenta_ia = "???"     # Qual ferramenta ...
# minha_ferramenta_ia = "???"     # Qual ferramenta de IA você mais usa?
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: minha_expectativa = "???"       # O que espera apr...
# minha_expectativa = "???"       # O que espera aprender nesta disciplina?
pass  # Substitua esta linha

# ── Cartão de apresentação ──
# O código abaixo usa suas variáveis para montar um cartão.
# Não precisa alterar nada aqui!

print("╔" + "═" * 50 + "╗")
print("║" + " 🎓 CARTÃO DO ALUNO — Prompt Engineering & AI".ljust(50) + "║")
print("╠" + "═" * 50 + "╣")
print(f"║  Nome:        {meu_nome:<35}║")
print(f"║  Turma:       {minha_turma:<35}║")
print(f"║  Idade:       {minha_idade} anos{'':<29}║")
print(f"║  IA favorita: {minha_ferramenta_ia:<35}║")
print("╠" + "═" * 50 + "╣")
print(f"║  Expectativa: {minha_expectativa[:35]:<35}║")
print("╚" + "═" * 50 + "╝")

# ── Curiosidade com cálculo ──
# Python também faz contas! Vamos calcular algo:
# dias_vividos = minha_idade * 365
pass  # Substitua esta linha
print(f"\n📊 Curiosidade: você já viveu aproximadamente {dias_vividos:,} dias!")
print(f"   E nesse tempo, a IA evoluiu de ELIZA (1966) até o ChatGPT (2022)!")

# %% [markdown]
# ---
# ## Exercício 3 — Análise de Sentimento com suas próprias frases ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 3 — Análise de Sentimento com suas próprias frases
# ============================================================
# Aqui vamos usar IA para detectar se uma frase é
# POSITIVA (feliz/boa) ou NEGATIVA (triste/ruim).

# Importar o pipeline da Hugging Face
# "Importar" = trazer uma ferramenta para poder usar
from transformers import pipeline

# Criar o pipeline de análise de sentimento
# Isso baixa um modelo de IA treinado (~260MB, pode demorar 1-2 min na primeira vez)
print("⏳ Carregando o modelo de IA... (pode demorar na primeira vez)")
# 👉 COMPLETE AQUI: analisador = pipeline("sentiment-analysis")...
# analisador = pipeline("sentiment-analysis")
pass  # Substitua esta linha
print("✅ Modelo carregado!\n")

# ✍️ TROQUE as frases abaixo por frases SUAS!
# Dica: use frases em inglês para melhor resultado
# (o modelo padrão foi treinado em inglês)
# minhas_frases = [
pass  # Substitua esta linha
    "I love studying at FIAP, the classes are amazing!",      # ✍️ Troque!
    "This traffic in São Paulo is terrible.",                   # ✍️ Troque!
    "Python is a very interesting programming language.",       # ✍️ Troque!
    "I am worried about my grades this semester.",              # ✍️ Troque!
    "The pizza I had yesterday was the best ever!",             # ✍️ Troque!
]

# Analisar cada frase
print("🔍 RESULTADO DA ANÁLISE DE SENTIMENTO\n")
# 👉 COMPLETE AQUI: print(f"{'Frase':<55} {'Sentimento':<12} {'Certeza...
# print(f"{'Frase':<55} {'Sentimento':<12} {'Certeza'}")
pass  # Substitua esta linha
print("─" * 80)

for frase in minhas_frases:
    # O pipeline retorna uma lista com um dicionário dentro
    # Por isso usamos [0] para pegar o primeiro (e único) resultado
    # resultado = analisador(frase)[0]
    pass  # Substitua esta linha

    # resultado tem dois campos:
    # - 'label': POSITIVE ou NEGATIVE
    # - 'score': de 0 a 1 (quanto mais perto de 1, mais certeza)

    # label = resultado['label']       # POSITIVE ou NEGATIVE
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: score = resultado['score']       # número entre 0 ...
    # score = resultado['score']       # número entre 0 e 1
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: emoji = "😊" if label == "POSITIVE" else "😟"...
    # emoji = "😊" if label == "POSITIVE" else "😟"
    pass  # Substitua esta linha

    # Mostrar resultado formatado
    # print(f"  {emoji} {frase[:53]:<53} {label:<12} {score:.1%}")
    pass  # Substitua esta linha

print("\n💡 Observou algo interessante?")
print("   • Frases com palavras como 'love', 'best', 'amazing' tendem a ser POSITIVE")
print("   • Frases com 'terrible', 'worried', 'bad' tendem a ser NEGATIVE")
print("   • A IA acerta na maioria, mas pode errar em frases com sarcasmo ou ironia!")

# %% [markdown]
# ---
# ## Exercício 4 — Geração de Texto com Diferentes Temperaturas ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 4 — Geração de Texto com Diferentes Temperaturas
# ============================================================

from transformers import pipeline

# Criar o gerador de texto usando o modelo GPT-2
# GPT-2 é um modelo antigo (2019), pequeno, mas serve para aprender!
print("⏳ Carregando GPT-2...")
# 👉 COMPLETE AQUI: gerador = pipeline("text-generation", model="gpt2"...
# gerador = pipeline("text-generation", model="gpt2")
pass  # Substitua esta linha
print("✅ GPT-2 carregado!\n")

# ✍️ ESCOLHA UM PROMPT (início de frase para a IA completar)
# Troque por qualquer frase em inglês que você quiser!
# meu_prompt = "Artificial intelligence will change the future because"
pass  # Substitua esta linha

# Vamos testar 3 temperaturas diferentes com o MESMO prompt
# temperaturas = [0.1, 0.7, 1.5]
pass  # Substitua esta linha

print(f"📝 Seu prompt: \"{meu_prompt}\"")
# 👉 COMPLETE AQUI: print("=" * 70)...
# print("=" * 70)
pass  # Substitua esta linha

for temp in temperaturas:
    # Gerar texto
    # resultado = gerador(
    pass  # Substitua esta linha
        meu_prompt,           # O texto inicial
        # 👉 COMPLETE AQUI: max_length=60,        # Máximo de palavras (tokens...
        # max_length=60,        # Máximo de palavras (tokens) no total
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: temperature=temp,     # A "criatividade"...
        # temperature=temp,     # A "criatividade"
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: do_sample=True,       # Permite variação (necessár...
        # do_sample=True,       # Permite variação (necessário com temperature)
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: num_return_sequences=1,  # Quantas respostas gerar...
        # num_return_sequences=1,  # Quantas respostas gerar
        pass  # Substitua esta linha
    )

    # O resultado é uma lista com dicionários
    # texto_gerado = resultado[0]['generated_text']
    pass  # Substitua esta linha

    # Mostrar apenas a parte que a IA GEROU (sem o prompt original)
    # parte_nova = texto_gerado[len(meu_prompt):]
    pass  # Substitua esta linha

    if temp == 0.1:
        emoji = "🧊"
        descricao = "FRIA (previsível)"
    elif temp == 0.7:
        emoji = "🌤️"
        descricao = "MORNA (equilibrada)"
    else:
        emoji = "🔥"
        descricao = "QUENTE (criativa)"

    print(f"\n{emoji} Temperatura {temp} — {descricao}")
    print(f"   {parte_nova.strip()[:150]}")

print("\n" + "=" * 70)
print("\n🤔 PERGUNTAS PARA REFLEXÃO:")
print("   1. Qual temperatura gerou o texto mais coerente?")
print("   2. Qual gerou o texto mais criativo?")
print("   3. Em qual cenário você usaria temperatura baixa? E alta?")

# %%
# ============================================================
# EXERCÍCIO 4b — Agora é sua vez! Teste com prompts diferentes
# ============================================================
# Tente estes prompts ou crie os seus:

# 👉 COMPLETE AQUI: prompts_para_testar = [...
# prompts_para_testar = [
pass  # Substitua esta linha
    "The best programming language for beginners is",
    "In 2030, robots will",
    "The secret to learning fast is",
    # ✍️ Adicione seus próprios prompts aqui!
]

# print("🧪 TESTANDO VÁRIOS PROMPTS (temperatura = 0.7)\n")
pass  # Substitua esta linha

for prompt in prompts_para_testar:
    # 👉 COMPLETE AQUI: resultado = gerador(...
    # resultado = gerador(
    pass  # Substitua esta linha
        prompt,
        # 👉 COMPLETE AQUI: max_length=50,...
        # max_length=50,
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: temperature=0.7,...
        # temperature=0.7,
        pass  # Substitua esta linha
        do_sample=True,
    )
    texto = resultado[0]['generated_text']
    print(f"  📝 Prompt:  {prompt}")
    print(f"  🤖 IA:      {texto[len(prompt):].strip()[:120]}")
    print()

# %% [markdown]
# ---
# ## Exercício 5 — Quiz sobre IA (interativo!) ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 5 — Quiz sobre IA (interativo!)
# ============================================================
# Execute esta célula e responda as perguntas!
# No Google Colab, vai aparecer uma caixinha para você digitar.

# Lista de perguntas: cada pergunta é um dicionário com
# a pergunta, as opções, a resposta correta e uma explicação
# 👉 COMPLETE AQUI: quiz = [...
# quiz = [
pass  # Substitua esta linha
    {
        "pergunta": "O que significa a sigla 'IA'?",
        "opcoes": ["A) Internet Avançada", "B) Inteligência Artificial",
                   "C) Informação Automatizada", "D) Interface de Aplicação"],
        "correta": "B",
        # 👉 COMPLETE AQUI: "explicacao": "IA = Inteligência Artificial (Artif...
        # "explicacao": "IA = Inteligência Artificial (Artificial Intelligence em inglês)"
        pass  # Substitua esta linha
    },
    {
        "pergunta": "Qual destes é um exemplo de IA Generativa?",
        "opcoes": ["A) Google Maps", "B) Calculadora do celular",
                   "C) ChatGPT", "D) Microsoft Excel"],
        "correta": "C",
        "explicacao": "O ChatGPT gera texto novo — isso é IA Generativa!"
    },
    {
        "pergunta": "Em que ano foi criado o Teste de Turing?",
        "opcoes": ["A) 1900", "B) 1950", "C) 1997", "D) 2022"],
        "correta": "B",
        "explicacao": "Alan Turing propôs o teste em 1950: 'Máquinas podem pensar?'"
    },
    {
        "pergunta": "O que o Deep Blue fez em 1997?",
        "opcoes": ["A) Criou a internet", "B) Venceu o campeão mundial de xadrez",
                   "C) Traduziu idiomas", "D) Reconheceu rostos"],
        "correta": "B",
        "explicacao": "Deep Blue (IBM) venceu Garry Kasparov, campeão mundial de xadrez!"
    },
    {
        "pergunta": "Machine Learning é uma subárea de:",
        "opcoes": ["A) Internet das Coisas", "B) Banco de Dados",
                   "C) Inteligência Artificial", "D) Redes de Computadores"],
        "correta": "C",
        "explicacao": "ML é uma subárea da IA que aprende a partir de dados."
    },
    {
        "pergunta": "'LLM' significa:",
        "opcoes": ["A) Large Language Model", "B) Low Level Machine",
                   "C) Linear Learning Method", "D) Local Language Manager"],
        "correta": "A",
        # 👉 COMPLETE AQUI: "explicacao": "LLM = Large Language Model (Modelo ...
        # "explicacao": "LLM = Large Language Model (Modelo de Linguagem de Grande Escala)"
        pass  # Substitua esta linha
    },
    {
        "pergunta": "Qual destas ferramentas é 100% GRATUITA para programar com IA?",
        "opcoes": ["A) Google Colab", "B) Apenas softwares pagos servem",
                   "C) Só funciona com computador de R$10.000", "D) Não existe ferramenta gratuita"],
        "correta": "A",
        "explicacao": "Google Colab é gratuito e roda na nuvem — é o que usamos nesta disciplina!"
    },
    {
        "pergunta": "O paper 'Attention Is All You Need' (2017) introduziu qual arquitetura?",
        "opcoes": ["A) CNN (Rede Convolucional)", "B) Random Forest",
                   "C) Transformer", "D) Decision Tree"],
        "correta": "C",
        "explicacao": "O Transformer é a base de TODOS os LLMs modernos (GPT, Claude, Gemini, LLaMA)."
    },
]

# ── Rodar o quiz ──
# pontos = 0
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: total = len(quiz)...
# total = len(quiz)
pass  # Substitua esta linha

print("🧠 QUIZ — O QUE É INTELIGÊNCIA ARTIFICIAL?")
# 👉 COMPLETE AQUI: print(f"   {total} perguntas • Boa sorte!\n")...
# print(f"   {total} perguntas • Boa sorte!\n")
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: print("=" * 50)...
# print("=" * 50)
pass  # Substitua esta linha

for i, q in enumerate(quiz, 1):
    # 👉 COMPLETE AQUI: print(f"\nPergunta {i}/{total}: {q['pergunta']}\n"...
    # print(f"\nPergunta {i}/{total}: {q['pergunta']}\n")
    pass  # Substitua esta linha
    for opcao in q['opcoes']:
        # 👉 COMPLETE AQUI: print(f"   {opcao}")...
        # print(f"   {opcao}")
        pass  # Substitua esta linha

    # Pedir resposta (input espera o usuário digitar)
    # resposta = input(f"\n   Sua resposta (A/B/C/D): ").strip().upper()
    pass  # Substitua esta linha

    # Verificar se acertou
    if resposta == q['correta']:
        # 👉 COMPLETE AQUI: pontos += 1...
        # pontos += 1
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: print(f"   ✅ CORRETO! {q['explicacao']}")...
        # print(f"   ✅ CORRETO! {q['explicacao']}")
        pass  # Substitua esta linha
    else:
        # 👉 COMPLETE AQUI: print(f"   ❌ Errou! A resposta era {q['correta']}....
        # print(f"   ❌ Errou! A resposta era {q['correta']}.")
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: print(f"   📖 {q['explicacao']}")...
        # print(f"   📖 {q['explicacao']}")
        pass  # Substitua esta linha

# ── Resultado Final ──
# print("\n" + "=" * 50)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: print(f"\n🏆 RESULTADO FINAL: {pontos}/{total} acer...
# print(f"\n🏆 RESULTADO FINAL: {pontos}/{total} acertos ({pontos/total*100:.0f}%)")
pass  # Substitua esta linha

if pontos == total:
    print("🌟 PERFEITO! Você dominou os conceitos da Aula 01!")
# 👉 COMPLETE AQUI: elif pontos >= total * 0.7:...
# elif pontos >= total * 0.7:
pass  # Substitua esta linha
    print("👏 Muito bem! Você entendeu a maioria dos conceitos!")
# 👉 COMPLETE AQUI: elif pontos >= total * 0.5:...
# elif pontos >= total * 0.5:
pass  # Substitua esta linha
    print("📚 Bom começo! Revise os tópicos que errou.")
else:
    print("💪 Não desanime! Revise o material da Aula 01 e tente novamente.")

# %% [markdown]
# ---
# ## Exercício 6 — Investigando Modelos no Hugging Face ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 6 — Investigando Modelos no Hugging Face
# ============================================================
from huggingface_hub import HfApi

# Criar conexão com o Hugging Face
# "API" = Application Programming Interface
# É uma forma de um programa conversar com outro programa
# 👉 COMPLETE AQUI: api = HfApi()...
# api = HfApi()
pass  # Substitua esta linha

# Buscar os modelos mais baixados de geração de texto
print("🔍 MODELOS MAIS POPULARES DE GERAÇÃO DE TEXTO\n")
print(f"{'#':<4} {'Modelo':<45} {'Downloads':<15} {'Likes'}")
print("─" * 80)

# modelos = api.list_models(
pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: task="text-generation",  # Filtrar: só modelos de ...
    # task="text-generation",  # Filtrar: só modelos de geração de texto
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: sort="downloads",        # Ordenar: mais baixados ...
    # sort="downloads",        # Ordenar: mais baixados primeiro
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: limit=10                 # Limitar: top 10...
    # limit=10                 # Limitar: top 10
    pass  # Substitua esta linha
)

for i, modelo in enumerate(modelos, 1):
    nome = modelo.id[:43]
    downloads = f"{modelo.downloads:,}" if modelo.downloads else "?"
    likes = modelo.likes if modelo.likes else 0
    print(f"  {i:<3} {nome:<44} {downloads:<14} ❤️ {likes}")

print("\n💡 Esses são modelos REAIS que milhões de pessoas usam!")
print("   Alguns deles (como GPT-2) vamos usar nesta disciplina.")

# %%
# ============================================================
# EXERCÍCIO 6b — Comparando diferentes TAREFAS de IA
# ============================================================
# A Hugging Face organiza modelos por "tarefa" (task).
# Cada tarefa é algo diferente que a IA sabe fazer.

# 👉 COMPLETE AQUI: tarefas = [...
# tarefas = [
pass  # Substitua esta linha
    ("text-generation", "📝 Gerar texto"),
    ("text-classification", "🏷️ Classificar texto"),
    ("image-classification", "🖼️ Classificar imagens"),
    ("translation", "🌐 Traduzir idiomas"),
    ("summarization", "📄 Resumir textos"),
    ("question-answering", "❓ Responder perguntas"),
    ("text-to-image", "🎨 Gerar imagens"),
]

print("📊 TAREFAS DE IA NO HUGGING FACE\n")
print("Cada tarefa tem centenas ou milhares de modelos disponíveis.\n")

for task_id, descricao in tarefas:
    try:
        # 👉 COMPLETE AQUI: modelos = list(api.list_models(task=task_id, sort=...
        # modelos = list(api.list_models(task=task_id, sort="downloads", limit=1))
        pass  # Substitua esta linha
        if modelos:
            # 👉 COMPLETE AQUI: top = modelos[0]...
            # top = modelos[0]
            pass  # Substitua esta linha
            # 👉 COMPLETE AQUI: print(f"  {descricao}")...
            # print(f"  {descricao}")
            pass  # Substitua esta linha
            # 👉 COMPLETE AQUI: print(f"    🏆 Top modelo: {top.id}")...
            # print(f"    🏆 Top modelo: {top.id}")
            pass  # Substitua esta linha
            # 👉 COMPLETE AQUI: print(f"    📥 Downloads: {top.downloads:,}\n")...
            # print(f"    📥 Downloads: {top.downloads:,}\n")
            pass  # Substitua esta linha
        else:
            # 👉 COMPLETE AQUI: print(f"  {descricao} — nenhum modelo encontrado\n...
            # print(f"  {descricao} — nenhum modelo encontrado\n")
            pass  # Substitua esta linha
    except:
        # 👉 COMPLETE AQUI: print(f"  {descricao} — erro ao buscar\n")...
        # print(f"  {descricao} — erro ao buscar\n")
        pass  # Substitua esta linha

# ── Perguntas para reflexão ──
# print("=" * 55)
pass  # Substitua esta linha
print("\n🤔 PERGUNTAS PARA RESPONDER:")
print("   (escreva suas respostas na célula abaixo)\n")
print("   1. Qual tarefa tem o modelo mais baixado?")
print("   2. Qual tarefa você acha mais útil no seu dia a dia?")
print("   3. Você reconhece algum nome de modelo? Qual?")
print("   4. Qual tarefa você gostaria de aprender a usar nesta disciplina?")

# %% [markdown]
# ---
# ## Exercício 7 — Construindo um testador de IA ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 7 — Construindo um testador de IA
# ============================================================
from transformers import pipeline

# Carregar o modelo (se já carregou antes, isso será rápido)
# 👉 COMPLETE AQUI: gerador = pipeline("text-generation", model="gpt2"...
# gerador = pipeline("text-generation", model="gpt2")
pass  # Substitua esta linha

# ✍️ COMPLETE A FUNÇÃO ABAIXO
# Dicas:
# - Use gerador() para gerar texto
# - O resultado vem como: resultado[0]['generated_text']
# - Use print() para mostrar na tela

# def testar_ia(prompt, temperatura=0.7):
pass  # Substitua esta linha
    # Funcao que testa a IA com um prompt e mostra o resultado.
    #
    # O que e "def"?
    # "def" vem de "define" -- estamos DEFININDO uma nova funcao.
    #
    # O que e um parametro?
    # Sao os valores que a funcao recebe para trabalhar.
    # "prompt" e o texto inicial.
    # "temperatura" e a criatividade (tem valor padrao 0.7).

    # Passo 1: Chamar o gerador com o prompt
    # ✍️ Descomente a linha abaixo e complete:
    # resultado = gerador(prompt, max_length=???, temperature=???, do_sample=True)

    # Passo 2: Extrair o texto gerado
    # ✍️ Descomente a linha abaixo:
    # texto = resultado[0]['generated_text']

    # Passo 3: Mostrar o resultado formatado
    # ✍️ Descomente as linhas abaixo:
    # print(f"📝 Prompt:      {prompt}")
    # print(f"🌡️ Temperatura: {temperatura}")
    # print(f"🤖 IA gerou:    {texto[len(prompt):].strip()[:120]}")
    # print()

    pass  # ← Remova esta linha quando completar a função!


# ── Testar a função ──
# Depois de completar a função acima, descomente as linhas abaixo:

# testar_ia("The future of education is")
# testar_ia("Python is a great language because")
# testar_ia("The most important skill in 2026 is")
# testar_ia("The future of education is", temperatura=0.1)   # Fria
# testar_ia("The future of education is", temperatura=1.5)   # Quente

# %% [markdown]
# ---
# ## Exercício 8 — Detector de Emoções com Gráfico ⭐⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 8 — Detector de Emoções com Gráfico
# ============================================================
from transformers import pipeline
import matplotlib.pyplot as plt

# Modelo que classifica emoções (6 emoções diferentes!)
# Este modelo detecta: joy, sadness, anger, fear, surprise, love
print("⏳ Carregando modelo de emoções...")
# 👉 COMPLETE AQUI: detector_emocao = pipeline(...
# detector_emocao = pipeline(
pass  # Substitua esta linha
    "text-classification",
    # 👉 COMPLETE AQUI: model="bhadresh-savani/distilbert-base-uncased-emo...
    # model="bhadresh-savani/distilbert-base-uncased-emotion",
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: top_k=None  # Retorna TODAS as emoções com suas pr...
    # top_k=None  # Retorna TODAS as emoções com suas probabilidades
    pass  # Substitua esta linha
)
print("✅ Modelo carregado!\n")

# ✍️ ESCREVA FRASES SUAS AQUI (em inglês para melhor resultado)
# frases = [
pass  # Substitua esta linha
    "I just got accepted into FIAP! This is the best day ever!",
    "I am so angry that my code is not working after 3 hours.",
    "I don't know what will happen in the exam, I'm nervous.",
    "My friend surprised me with a birthday party!",
    "I miss my family, they live far away.",
    # ✍️ Adicione mais frases suas!
]

# ── Analisar cada frase e mostrar em gráfico ──
for frase in frases:
    # Detectar emoções
    # resultados = detector_emocao(frase)[0]
    pass  # Substitua esta linha

    # Separar dados para o gráfico
    # emocoes = [r['label'] for r in resultados]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: scores = [r['score'] for r in resultados]...
    # scores = [r['score'] for r in resultados]
    pass  # Substitua esta linha

    # Emoji para cada emoção
    # emoji_map = {
    pass  # Substitua esta linha
        "joy": "😊", "sadness": "😢", "anger": "😡",
        "fear": "😨", "surprise": "😲", "love": "❤️"
    }

    # Cor para cada emoção
    # cor_map = {
    pass  # Substitua esta linha
        "joy": "#ffd166", "sadness": "#6c63ff", "anger": "#ff6b6b",
        "fear": "#06b6d4", "surprise": "#00d4aa", "love": "#e91e63"
    }

    # Criar gráfico
    # fig, ax = plt.subplots(figsize=(10, 3))
    pass  # Substitua esta linha
    fig.patch.set_facecolor('#0d0f1a')
    ax.set_facecolor('#141628')

    # cores = [cor_map.get(e, "#888") for e in emocoes]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: labels = [f"{emoji_map.get(e, '')} {e}" for e in e...
    # labels = [f"{emoji_map.get(e, '')} {e}" for e in emocoes]
    pass  # Substitua esta linha

    # bars = ax.barh(labels, scores, color=cores, alpha=0.85, edgecolor='white', linewidth=0.5)
    pass  # Substitua esta linha

    # Mostrar porcentagem em cada barra
    for bar, score in zip(bars, scores):
        ax.text(bar.get_width() + 0.01, bar.get_y() + bar.get_height()/2,
                # 👉 COMPLETE AQUI: f'{score:.0%}', va='center', color='white', fontsi...
                # f'{score:.0%}', va='center', color='white', fontsize=10)
                pass  # Substitua esta linha

    ax.set_xlim(0, 1.15)
    # 👉 COMPLETE AQUI: ax.set_title(f'"{frase[:60]}..."', color='white', ...
    # ax.set_title(f'"{frase[:60]}..."', color='white', fontsize=10, pad=10)
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ax.tick_params(colors='white')...
    # ax.tick_params(colors='white')
    pass  # Substitua esta linha
    for spine in ax.spines.values():
        spine.set_color('#2a2d4a')
    plt.tight_layout()
    plt.show()

    # Emoção dominante
    top = resultados[0]
    print(f"  → Emoção dominante: {emoji_map.get(top['label'], '')} {top['label'].upper()} ({top['score']:.0%})\n")

# %% [markdown]
# ---
# ## Exercício 9 — App de IA (programa interativo) ⭐⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 9 — App de IA (programa interativo)
# ============================================================
# Este é um programa que oferece 3 ferramentas de IA
# e o usuário escolhe qual quer usar.

from transformers import pipeline

# Carregar os modelos (pode demorar um pouco)
print("⏳ Carregando modelos de IA...")
print("   (isso pode levar 1-2 minutos na primeira vez)\n")

# Modelo 1: Análise de sentimento
# 👉 COMPLETE AQUI: sentimento = pipeline("sentiment-analysis")...
# sentimento = pipeline("sentiment-analysis")
pass  # Substitua esta linha

# Modelo 2: Geração de texto
# gerador = pipeline("text-generation", model="gpt2")
pass  # Substitua esta linha

# Modelo 3: Preenchimento de lacuna (fill-mask)
# Este modelo recebe uma frase com [MASK] e adivinha a palavra!
# preenchedor = pipeline("fill-mask", model="distilbert-base-uncased")
pass  # Substitua esta linha

print("✅ Todos os modelos carregados!\n")

def menu():
    # Mostra o menu do app.
    print("\n╔══════════════════════════════════════╗")
    print("║   🤖 APP DE IA — FIAP 2026           ║")
    print("╠══════════════════════════════════════╣")
    print("║   1. 😊 Análise de Sentimento        ║")
    print("║   2. 📝 Completar Frases             ║")
    print("║   3. 🔮 Adivinhar Palavras           ║")
    print("║   0. 🚪 Sair                         ║")
    print("╚══════════════════════════════════════╝")

# ── Loop principal do app ──
# O programa fica rodando até o usuário digitar "0"

print("🎉 Bem-vindo ao App de IA!")
print("   Escolha uma ferramenta para testar.\n")

while True:
    menu()
    # 👉 COMPLETE AQUI: escolha = input("\n   Sua escolha (0-3): ").strip(...
    # escolha = input("\n   Sua escolha (0-3): ").strip()
    pass  # Substitua esta linha

    if escolha == "0":
        print("\n👋 Até a próxima aula! Tchau!")
        break

    # elif escolha == "1":
    pass  # Substitua esta linha
        print("\n😊 ANÁLISE DE SENTIMENTO")
        print("   (digite uma frase em inglês)")
        # 👉 COMPLETE AQUI: texto = input("   Sua frase: ")...
        # texto = input("   Sua frase: ")
        pass  # Substitua esta linha
        if texto:
            # 👉 COMPLETE AQUI: resultado = sentimento(texto)[0]...
            # resultado = sentimento(texto)[0]
            pass  # Substitua esta linha
            # 👉 COMPLETE AQUI: emoji = "😊" if resultado['label'] == 'POSITIVE' el...
            # emoji = "😊" if resultado['label'] == 'POSITIVE' else "😟"
            pass  # Substitua esta linha
            # 👉 COMPLETE AQUI: print(f"   {emoji} {resultado['label']} (certeza: ...
            # print(f"   {emoji} {resultado['label']} (certeza: {resultado['score']:.0%})")
            pass  # Substitua esta linha

    # elif escolha == "2":
    pass  # Substitua esta linha
        print("\n📝 COMPLETAR FRASES")
        print("   (digite o início de uma frase em inglês)")
        # 👉 COMPLETE AQUI: texto = input("   Início da frase: ")...
        # texto = input("   Início da frase: ")
        pass  # Substitua esta linha
        if texto:
            # 👉 COMPLETE AQUI: resultado = gerador(texto, max_length=50, temperat...
            # resultado = gerador(texto, max_length=50, temperature=0.7, do_sample=True)
            pass  # Substitua esta linha
            # 👉 COMPLETE AQUI: gerado = resultado[0]['generated_text']...
            # gerado = resultado[0]['generated_text']
            pass  # Substitua esta linha
            # 👉 COMPLETE AQUI: print(f"   🤖 {gerado[:150]}")...
            # print(f"   🤖 {gerado[:150]}")
            pass  # Substitua esta linha

    # elif escolha == "3":
    pass  # Substitua esta linha
        print("\n🔮 ADIVINHAR PALAVRAS")
        print("   (digite uma frase com [MASK] onde quer que a IA adivinhe)")
        print("   Exemplo: 'Python is a [MASK] language'")
        # 👉 COMPLETE AQUI: texto = input("   Sua frase: ")...
        # texto = input("   Sua frase: ")
        pass  # Substitua esta linha
        if texto and "[MASK]" in texto:
            # 👉 COMPLETE AQUI: resultados = preenchedor(texto)...
            # resultados = preenchedor(texto)
            pass  # Substitua esta linha
            print("   🔮 Top 5 palavras que a IA sugere:")
            for r in resultados[:5]:
                # 👉 COMPLETE AQUI: barra = "█" * int(r['score'] * 40)...
                # barra = "█" * int(r['score'] * 40)
                pass  # Substitua esta linha
                # 👉 COMPLETE AQUI: print(f"      {r['token_str']:<15} {r['score']:.1%...
                # print(f"      {r['token_str']:<15} {r['score']:.1%} {barra}")
                pass  # Substitua esta linha
        else:
            print("   ⚠️ Inclua [MASK] na frase para a IA adivinhar!")

    else:
        print("   ⚠️ Opção inválida! Digite 0, 1, 2 ou 3.")

# %% [markdown]
# ---
# ## Exercício 10 — Pesquisa: IA no Brasil ⭐⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 10 — Pesquisa: IA no Brasil
# ============================================================
import matplotlib.pyplot as plt

# ✍️ PREENCHA COM SUA PESQUISA!
# Para cada empresa, preencha:
# - nome: nome da empresa
# - setor: área de atuação (fintech, saúde, varejo, etc.)
# - uso_ia: o que fazem com IA
# - impacto: número de impacto (ex: "40 milhões de clientes")

# 👉 COMPLETE AQUI: empresas_ia_brasil = [...
# empresas_ia_brasil = [
pass  # Substitua esta linha
    {
        "nome": "Nubank",
        "setor": "Fintech",
        "uso_ia": "Detecção de fraude e análise de crédito",
        "impacto": "100M+ de clientes"
    },
    {
        "nome": "???",        # ✍️ Pesquise e preencha!
        "setor": "???",
        "uso_ia": "???",
        "impacto": "???"
    },
    {
        "nome": "???",        # ✍️ Pesquise e preencha!
        "setor": "???",
        "uso_ia": "???",
        "impacto": "???"
    },
    {
        "nome": "???",        # ✍️ Pesquise e preencha!
        "setor": "???",
        "uso_ia": "???",
        "impacto": "???"
    },
    {
        "nome": "???",        # ✍️ Pesquise e preencha!
        "setor": "???",
        "uso_ia": "???",
        "impacto": "???"
    },
]

# ── Gerar relatório ──
print("📊 RELATÓRIO: IA NO MERCADO BRASILEIRO\n")
# 👉 COMPLETE AQUI: print(f"{'#':<4} {'Empresa':<18} {'Setor':<15} {'U...
# print(f"{'#':<4} {'Empresa':<18} {'Setor':<15} {'Uso de IA':<40} {'Impacto'}")
pass  # Substitua esta linha
print("═" * 95)

for i, emp in enumerate(empresas_ia_brasil, 1):
    # 👉 COMPLETE AQUI: print(f"  {i:<3} {emp['nome']:<17} {emp['setor']:<...
    # print(f"  {i:<3} {emp['nome']:<17} {emp['setor']:<14} {emp['uso_ia'][:38]:<39} {emp['impacto']}")
    pass  # Substitua esta linha

# ── Gráfico de setores ──
# Contar quantas empresas por setor
# setores = {}
pass  # Substitua esta linha
for emp in empresas_ia_brasil:
    # 👉 COMPLETE AQUI: setor = emp['setor']...
    # setor = emp['setor']
    pass  # Substitua esta linha
    if setor != "???":
        # 👉 COMPLETE AQUI: setores[setor] = setores.get(setor, 0) + 1...
        # setores[setor] = setores.get(setor, 0) + 1
        pass  # Substitua esta linha

if setores:
    # 👉 COMPLETE AQUI: fig, ax = plt.subplots(figsize=(8, 5))...
    # fig, ax = plt.subplots(figsize=(8, 5))
    pass  # Substitua esta linha
    fig.patch.set_facecolor('#0d0f1a')
    ax.set_facecolor('#141628')

    # cores = ['#6c63ff', '#00d4aa', '#ffd166', '#ff6b6b', '#06b6d4', '#e91e63']
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ax.bar(setores.keys(), setores.values(), color=cor...
    # ax.bar(setores.keys(), setores.values(), color=cores[:len(setores)],
    pass  # Substitua esta linha
           # 👉 COMPLETE AQUI: alpha=0.85, edgecolor='white', linewidth=0.5)...
           # alpha=0.85, edgecolor='white', linewidth=0.5)
           pass  # Substitua esta linha
    ax.set_title("Setores que mais usam IA no Brasil (sua pesquisa)",
                 # 👉 COMPLETE AQUI: color='white', fontsize=12, fontweight='bold')...
                 # color='white', fontsize=12, fontweight='bold')
                 pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ax.set_ylabel("Quantidade de empresas", color='whi...
    # ax.set_ylabel("Quantidade de empresas", color='white')
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ax.tick_params(colors='white')...
    # ax.tick_params(colors='white')
    pass  # Substitua esta linha
    for spine in ax.spines.values():
        spine.set_color('#2a2d4a')
    plt.tight_layout()
    plt.show()

# Contar progresso
# preenchidos = sum(1 for e in empresas_ia_brasil if e['nome'] != '???')
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: print(f"\n📊 Progresso: {preenchidos}/{len(empresas...
# print(f"\n📊 Progresso: {preenchidos}/{len(empresas_ia_brasil)} empresas pesquisadas")
pass  # Substitua esta linha

if preenchidos < 5:
    print("\n💡 Dica: pesquise por 'empresas brasileiras que usam inteligência artificial'")
    print("   Algumas para começar: iFood, Stone, Totvs, Vtex, C6 Bank, Magazine Luiza, Loft")

# %% [markdown]
# ---
# ## 🎉 Parabéns!
#
# Você completou os 10 exercícios da **Aula 01 — O que é IA?**!
#
# **O que você aprendeu:**
# - Cada exercício praticou um conceito diferente da aula
# - Você escreveu código Python funcional no Google Colab
# - Os conceitos se conectam com o conteúdo teórico da aula
#
# **Salve seu notebook** (File → Save) para não perder o progresso!
