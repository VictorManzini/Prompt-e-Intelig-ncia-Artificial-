# %% [markdown]
# # 📝 Exercícios Práticos — Aula 03: Como Funcionam os LLMs
#
# **Disciplina:** Prompt Engineering and Artificial Intelligence
# **Instituição:** FIAP — Ciência da Computação · 2026
# **Professor:** Jorge Luiz Gomes
# **Módulo 1 — Fundamentos de IA**
#
# ---
#
# ## 📋 Instruções
#
# - **5 exercícios** com nível de dificuldade crescente
# - Em cada exercício, complete as partes marcadas com `# 👉 COMPLETE AQUI`
# - **NÃO apague** o código existente — apenas substitua as linhas com `pass`
# - As linhas comentadas logo acima do `pass` são **dicas** do que escrever
# - Execute cada célula com `Shift + Enter` e verifique se funciona
# - Se travar, releia a explicação acima do código
#
# > 💡 **Dica:** A linha comentada com `#` logo acima do `pass` mostra EXATAMENTE o que você precisa escrever. Use como referência!
#
# ---

# %% [markdown]
# ## 🔧 Setup — Execute esta célula primeiro
#
# Instala e importa todas as bibliotecas necessárias. **Não modifique nada aqui.**

# %%
# !pip install -q tiktoken sentence-transformers transformers matplotlib scikit-learn numpy
print('✅ Instalado!')

# %% [markdown]
# ---
# ## Exercício 1 — Contador de Tokens + Estimativa de Custo ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 1 — Contador de Tokens + Estimativa de Custo
# ============================================================
import tiktoken

# 👉 COMPLETE AQUI: enc = tiktoken.get_encoding("cl100k_base")  # Toke...
# enc = tiktoken.get_encoding("cl100k_base")  # Tokenizador do GPT-4
pass  # Substitua esta linha

# ✍️ Adicione seus próprios textos!
# textos = [
pass  # Substitua esta linha
    "Olá, mundo!",
    "Hello, world!",
    "Inteligência Artificial é o futuro da computação.",
    "Artificial Intelligence is the future of computing.",
    # 👉 COMPLETE AQUI: "def calcular_media(notas): return sum(notas) / le...
    # "def calcular_media(notas): return sum(notas) / len(notas)",
    pass  # Substitua esta linha
    "pneumoultramicroscopicossilicovulcanoconiótico",  # Palavra grande!
]

# Custo simulado (GPT-4 cobra ~$0.03 por 1K tokens de input)
# custo_por_1k = 0.03
pass  # Substitua esta linha

print("🔤 CONTADOR DE TOKENS\n")
print(f"{'Texto':<55} {'Tokens':>7}  {'Custo':>8}  Tokenização")
print("═" * 110)

for texto in textos:
    # 👉 COMPLETE AQUI: tokens = enc.encode(texto)...
    # tokens = enc.encode(texto)
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: custo = (len(tokens) / 1000) * custo_por_1k...
    # custo = (len(tokens) / 1000) * custo_por_1k
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: partes = [enc.decode([t]) for t in tokens[:6]]...
    # partes = [enc.decode([t]) for t in tokens[:6]]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: extras = "..." if len(tokens) > 6 else ""...
    # extras = "..." if len(tokens) > 6 else ""
    pass  # Substitua esta linha
    print(f"  {texto[:53]:<53} {len(tokens):>5}    ${custo:.5f}   {partes}{extras}")

print("\n💡 OBSERVAÇÕES:")
print("   • Português usa MAIS tokens que inglês (palavras são quebradas)")
print("   • Código também é tokenizado (cada símbolo pode ser 1 token)")
print("   • Palavras raras/longas custam muitos tokens")

# ✍️ Desafio: qual texto tem MAIS tokens?
print("\n🏆 Texto com mais tokens:", max(textos, key=lambda t: len(enc.encode(t))))

# %% [markdown]
# ---
# ## Exercício 2 — Similaridade entre frases ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 2 — Similaridade entre frases
# ============================================================
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# 👉 COMPLETE AQUI: modelo = SentenceTransformer('all-MiniLM-L6-v2')...
# modelo = SentenceTransformer('all-MiniLM-L6-v2')
pass  # Substitua esta linha

# ✍️ Crie pares de frases para testar!
# pares = [
pass  # Substitua esta linha
    ("I love dogs", "I adore puppies"),
    ("I love dogs", "The weather is sunny"),
    ("Python is great for AI", "Machine learning uses Python"),
    ("I ate pizza for lunch", "I had pizza at noon"),
    ("The stock market crashed", "I like ice cream"),
    # ✍️ Adicione seus próprios pares!
]

print("🔗 CALCULADORA DE SIMILARIDADE SEMÂNTICA\n")
print(f"  {'Frase A':<35} {'Frase B':<35} {'Similaridade':>12}")
print("  " + "═" * 85)

for a, b in pares:
    # 👉 COMPLETE AQUI: emb = modelo.encode([a, b])...
    # emb = modelo.encode([a, b])
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: sim = cosine_similarity([emb[0]], [emb[1]])[0][0]...
    # sim = cosine_similarity([emb[0]], [emb[1]])[0][0]
    pass  # Substitua esta linha

    # Barra visual
    # barra = "█" * int(sim * 20) + "░" * (20 - int(sim * 20))
    pass  # Substitua esta linha

    # Emoji baseado na similaridade
    if sim > 0.7: emoji = "🟢"
    # 👉 COMPLETE AQUI: elif sim > 0.4: emoji = "🟡"...
    # elif sim > 0.4: emoji = "🟡"
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: else: emoji = "🔴"...
    # else: emoji = "🔴"
    pass  # Substitua esta linha

    print(f"  {a[:33]:<35} {b[:33]:<35} {emoji} {sim:.1%} {barra}")

print("\n💡 ESCALA:")
# 👉 COMPLETE AQUI: print("   🟢 > 70% = Muito similares (mesmo assunto...
# print("   🟢 > 70% = Muito similares (mesmo assunto)")
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: print("   🟡 40-70% = Relacionados")...
# print("   🟡 40-70% = Relacionados")
pass  # Substitua esta linha
print("   🔴 < 40% = Assuntos diferentes")

# %% [markdown]
# ---
# ## Exercício 3 — Mapa visual de embeddings ⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 3 — Mapa visual de embeddings
# ============================================================
from sentence_transformers import SentenceTransformer
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# 👉 COMPLETE AQUI: modelo = SentenceTransformer('all-MiniLM-L6-v2')...
# modelo = SentenceTransformer('all-MiniLM-L6-v2')
pass  # Substitua esta linha

# ✍️ Crie listas de palavras/frases por CATEGORIA
# categorias = {
pass  # Substitua esta linha
    "Programação": ["Python code", "JavaScript function", "debug error", "compile program", "git commit"],
    "Comida": ["pizza delivery", "sushi restaurant", "chocolate cake", "grilled chicken", "fresh salad"],
    "Esportes": ["football match", "basketball game", "swimming pool", "tennis racket", "running marathon"],
    "Música": ["guitar solo", "piano concert", "rock band", "jazz club", "singing voice"],
}

# cores = {'Programação': '#6c63ff', 'Comida': '#00d4aa', 'Esportes': '#ff6b6b', 'Música': '#ffd166'}
pass  # Substitua esta linha

# todas_frases = []
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: todas_cats = []...
# todas_cats = []
pass  # Substitua esta linha
for cat, frases in categorias.items():
    todas_frases.extend(frases)
    todas_cats.extend([cat] * len(frases))

# embeddings = modelo.encode(todas_frases)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: pca = PCA(n_components=2)...
# pca = PCA(n_components=2)
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: coords = pca.fit_transform(embeddings)...
# coords = pca.fit_transform(embeddings)
pass  # Substitua esta linha

# fig, ax = plt.subplots(figsize=(12, 8))
pass  # Substitua esta linha
fig.patch.set_facecolor('#0d0f1a')
ax.set_facecolor('#141628')

for cat in categorias:
    # 👉 COMPLETE AQUI: mask = [c == cat for c in todas_cats]...
    # mask = [c == cat for c in todas_cats]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: xs = coords[mask, 0]...
    # xs = coords[mask, 0]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ys = coords[mask, 1]...
    # ys = coords[mask, 1]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: ax.scatter(xs, ys, c=cores[cat], s=120, label=cat,...
    # ax.scatter(xs, ys, c=cores[cat], s=120, label=cat, alpha=0.8, edgecolors='white', linewidths=0.5)
    pass  # Substitua esta linha
    for x, y, frase in zip(xs, ys, [f for f, c in zip(todas_frases, todas_cats) if c == cat]):
        ax.annotate(frase, (x, y), textcoords="offset points", xytext=(8, 8),
                    fontsize=7.5, color='white', alpha=0.85)

ax.legend(facecolor='#1a1040', labelcolor='white', fontsize=10)
ax.set_title("Mapa de Embeddings — Textos similares ficam próximos", color='white', fontsize=14, fontweight='bold')
ax.tick_params(colors='white')
for s in ax.spines.values(): s.set_color('#2a2d4a')
plt.tight_layout()
plt.show()

print("💡 Cada categoria formou um CLUSTER (grupo)!")
print("   Isso mostra que embeddings capturam SIGNIFICADO, não apenas palavras.")

# %% [markdown]
# ---
# ## Exercício 4 — Medindo o efeito da temperatura ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 4 — Medindo o efeito da temperatura
# ============================================================
from transformers import pipeline
from collections import Counter

# 👉 COMPLETE AQUI: gerador = pipeline("text-generation", model="gpt2"...
# gerador = pipeline("text-generation", model="gpt2")
pass  # Substitua esta linha

# prompt = "The most important thing about artificial intelligence is"
pass  # Substitua esta linha
# 👉 COMPLETE AQUI: temperaturas = [0.1, 0.3, 0.5, 0.7, 1.0, 1.5]...
# temperaturas = [0.1, 0.3, 0.5, 0.7, 1.0, 1.5]
pass  # Substitua esta linha

print(f"📝 Prompt: '{prompt}'\n")

for temp in temperaturas:
    # Gerar 3 vezes com a mesma temperatura
    # textos = []
    pass  # Substitua esta linha
    for _ in range(3):
        # 👉 COMPLETE AQUI: r = gerador(prompt, max_length=40, temperature=tem...
        # r = gerador(prompt, max_length=40, temperature=temp, do_sample=True)
        pass  # Substitua esta linha
        # 👉 COMPLETE AQUI: texto = r[0]['generated_text'][len(prompt):].strip...
        # texto = r[0]['generated_text'][len(prompt):].strip()
        pass  # Substitua esta linha
        textos.append(texto[:80])

    # Medir se os 3 são iguais (repetitividade)
    # unicos = len(set(textos))
    pass  # Substitua esta linha
    if temp <= 0.3:
        # 👉 COMPLETE AQUI: emoji = "🧊"...
        # emoji = "🧊"
        pass  # Substitua esta linha
    elif temp <= 0.7:
        emoji = "🌤️"
    else:
        emoji = "🔥"

    print(f"{emoji} Temperatura {temp} — {unicos}/3 textos únicos")
    for i, t in enumerate(textos, 1):
        print(f"   {i}. {t[:75]}")
    print()

print("💡 Temperatura BAIXA → textos quase idênticos (determinístico)")
print("   Temperatura ALTA → textos muito diferentes (criativo/caótico)")

# %% [markdown]
# ---
# ## Exercício 5 — Analogia vetorial ⭐⭐
#
# **O que você vai fazer:**
# - Leia o código abaixo com atenção
# - As linhas com `# 👉 COMPLETE AQUI` indicam onde você deve escrever
# - A linha comentada (`#`) logo abaixo é a **dica** — ela mostra o código que você precisa escrever
# - Substitua o `pass` pelo código correto
# - Execute a célula e verifique se o output faz sentido

# %%
# ============================================================
# EXERCÍCIO 5 — Analogia vetorial
# ============================================================
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# 👉 COMPLETE AQUI: modelo = SentenceTransformer('all-MiniLM-L6-v2')...
# modelo = SentenceTransformer('all-MiniLM-L6-v2')
pass  # Substitua esta linha

def analogia(a, b, c, candidatos):
    """Resolve: A está para B assim como C está para ?"""
    # 👉 COMPLETE AQUI: embs = modelo.encode([a, b, c] + candidatos)...
    # embs = modelo.encode([a, b, c] + candidatos)
    pass  # Substitua esta linha
    # vetor_resultado = B - A + C
    # vetor = embs[1] - embs[0] + embs[2]
    pass  # Substitua esta linha
    # Encontrar candidato mais próximo
    # sims = cosine_similarity([vetor], embs[3:])[0]
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: melhor_idx = np.argmax(sims)...
    # melhor_idx = np.argmax(sims)
    pass  # Substitua esta linha
    # 👉 COMPLETE AQUI: return candidatos[melhor_idx], sims[melhor_idx]...
    # return candidatos[melhor_idx], sims[melhor_idx]
    pass  # Substitua esta linha

# ✍️ Teste suas próprias analogias!
# testes = [
pass  # Substitua esta linha
    ("king", "queen", "man", ["woman", "boy", "prince", "dog", "car"]),
    ("Paris", "France", "Tokyo", ["Japan", "China", "Brazil", "Germany", "Italy"]),
    ("hot", "cold", "big", ["small", "large", "warm", "fast", "slow"]),
    ("Python", "programming", "guitar", ["music", "code", "math", "cooking", "science"]),
]

print("🧮 ANALOGIAS VETORIAIS\n")
for a, b, c, cands in testes:
    # 👉 COMPLETE AQUI: resultado, score = analogia(a, b, c, cands)...
    # resultado, score = analogia(a, b, c, cands)
    pass  # Substitua esta linha
    print(f"  {a} → {b} :: {c} → ? ")
    print(f"  ✅ Resposta: {resultado} (similaridade: {score:.1%})")
    print(f"     Candidatos: {cands}\n")

# %% [markdown]
# ---
# ## 🎉 Parabéns!
#
# Você completou os 5 exercícios da **Aula 03 — Como Funcionam os LLMs**!
#
# **O que você aprendeu:**
# - Cada exercício praticou um conceito diferente da aula
# - Você escreveu código Python funcional no Google Colab
# - Os conceitos se conectam com o conteúdo teórico da aula
#
# **Salve seu notebook** (File → Save) para não perder o progresso!
